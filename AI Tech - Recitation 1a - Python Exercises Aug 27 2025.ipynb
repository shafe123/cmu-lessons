# %% [markdown]
# # A quick review

# %% [markdown]
# ### print() function, data types, values of expressions

# %%
# Guess what will be the outputs
print(3, '3', 3.0)

print('----------')

a = 3
b = '3'
c = 3.0

print('a is', a)
print('b is', b)
print('c is', c)

# %%
# Guess what will be the outputs
a = 3
b = '3'
c = 3.0

print('a is', a)
print('b is', b)

print('a + a is', a + a)
print('b + b is', b + b)

print('Is a equal to b?', a == b)
print('Is a equal to c?', a == c)

# %%
s = "10.8"
f = float(s)
# print(f / 2) # Guess what will be the result

val = "17"
# print(int(val) + 1) #


# print(int(s))  # Guess what will be the result

# %% [markdown]
# ### Please Complete: built-in functions

# %%
num = 3.56418
print(num, "rounded to ", round(num))

# display as 3.56
print(num, "rounded to", _______)

# display as 3.5642
print(num, "rounded to", _______)


print("value of |5-13| is", _______)
print("Square root of 16 is", _______)
print("value of pi is", _______)

# %% [markdown]
# ### Demo: Writing a simple program
#
# ### PROBLEM 0
#
# Write a program to convert 32 Celsius to Fahrenheit and display as below
# * `32 degrees Celsius is 89.6 degrees Fahrenheit`
#
#
# ![FAHRENHEIT_FORMULA.png](data:image/png;base64,...)

# %% [markdown]
# ### After that
#
# * Copy and revise the program to get the celsius value from user
# * Copy and revise it by adding a conversion function

# %% [markdown]
# ### f-strings and print

# %%
num = 3
print("Value is", num)
print("Value is " + str(num))
print(f"Value is {num}")

print(f"Double of {num} is {num * 2}")

# %%
num = 2603.3957


print(f"Value is {num}")
print('-----')
print(f"Value is {round(num, 3)}")
print(f"Value is {round(num, 2)}")
print('-----')
# print(f"Value is {num:.2f}")

# print(f"Value is {num:,.2f}")

# %% [markdown]
# #### Complete

# %%
# display the price as $100 using fstring
price = 100
print('Price: $' + str(price))

# use fstring
print(f'________________')

# %%
# increase the price 15% and display using fstring
price = 100

price = ___________
print('Price: $________')

# %%
# display 15% increased value of the price using fstring
price = 100
print(f'Price: $_________')

# %% [markdown]
# ### % and // operators

# %%
value = 12345
print(value)
print(value % 10)
print(value % 100)
print(value % 1000)

# %%
value = 12345
print(value)
print(value // 10)
print(value // 100)
print(value // 1000)
