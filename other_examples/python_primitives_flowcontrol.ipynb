# %% [markdown]
# # Python Primitives and Flow Control - Practice Notebook
# This notebook will give you practice problems on:
# - Primitive data types (integers, floats, strings, booleans)
# - Variables and type conversion
# - Conditionals (if/elif/else)
# - Loops (for, while)
# - Mini challenges

# %%
# --- Section 1: Primitive Data Types ---# Problem 1: Integers and Floatsx = 10      # integery = 2.5     # floatresult = x + yprint(result)print(type(result))# Problem 2: Stringss1 = "Hello"s2 = "World"message = s1 + " " + s2print(message)# Problem 3: Booleanscomparison = x > yprint(comparison)# --- Section 2: Type Conversion ---# Problem 4: Convert the string "42" into an integer and add 10.num_str = "42"num_int = int(num_str)print(num_int + 10)# Problem 5: Convert a float to an integer (e.g., 3.9).val = 3.9print(int(val))# --- Section 3: Conditionals ---# Problem 6: Check if a number is even or odd.num = 7if num % 2 == 0:    print("Even")else:    print("Odd")# Problem 7: Classify a number as positive, negative, or zero.n = -3if n > 0:    print("Positive")elif n < 0:    print("Negative")else:    print("Zero")# --- Section 4: Loops ---# Problem 8: Print the squares of numbers from 1 to 5.for i in range(1, 6):    print(i, i*i)# Problem 9: Print numbers from 5 down to 1.count = 5while count > 0:    print(count)    count -= 1# Problem 10: Print only even numbers from 1 to 10.for i in range(1, 11):    if i % 2 == 0:        print(i)# --- Section 5: Mini Challenges ---# Challenge 1: Sum of first 100 natural numberssum_total = 0for i in range(1, 101):    sum_total += iprint("Sum of first 100 natural numbers:", sum_total)# Challenge 2: Reverse a stringtext = "Python"reversed_text = ""for char in text:    reversed_text = char + reversed_textprint(reversed_text)# Challenge 3: FizzBuzz from 1 to 15for i in range(1, 16):    if i % 3 == 0 and i % 5 == 0:        print("FizzBuzz")    elif i % 3 == 0:        print("Fizz")    elif i % 5 == 0:        print("Buzz")    else:        print(i)
